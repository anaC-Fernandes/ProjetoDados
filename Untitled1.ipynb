# %% [markdown]
# <a href="https://colab.research.google.com/github/anaC-Fernandes/ProjetoDados/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (2.2.4)
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 48.8 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 64.3 MB/s eta 0:00:00m eta 0:00:0100:01
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: packaging>=20.0 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: numpy>=1.23 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib) (2.2.4)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Requirement already satisfied: pillow>=8 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 KB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pyparsing-3.2.3
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: pandas>=1.2 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: pillow>=8 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/drk/Área de Trabalho/config/py_venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anaC-Fernandes/ProjetoDados/refs/heads/main/BrStats.csv', sep = ";", low_memory=False)
df
# Out:
#         Ano  CDMunicipio Populacao PessoalOcupado PessoalAssalariado  \
# 0      2016      3509452     5.932            854                537
# 1      2016      3123601    27.505          5.680              4.778
# 2      2016      3552007     6.193            668                580
# 3      2016      3305604    21.279          3.087              2.669
# 4      2016      1717008     4.534            212                183
# ...     ...          ...       ...            ...                ...
# 33415  2021      2705408     7.171            463                436
# 33416  2021      1600105     9.265            428                383
# 33417  2019      2605459     3.061          2.210              1.773
# 33418  2020      1503002     7.070            538                514
# 33419  2021      3166709     8.725            852                773
#
#       VrSalarios      PIB  QtEmpresas  AreaPlantada_h  AreaColhida_h  ...  \
# 0         13.692  111.190       252.0            38.0           38.0  ...
# 1        104.977  554.663       671.0             3.0            3.0  ...
# 2         12.519   62.441        83.0             0.0            0.0  ...
# 3         80.161  403.121       290.0             0.0            0.0  ...
# 4          5.309   48.551        34.0            94.0           34.0  ...
# ...          ...      ...         ...             ...            ...  ...
# 33415     10.502      NaN        32.0             0.0            0.0  ...
# 33416      9.932      NaN        38.0             0.0            0.0  ...
# 33417     43.093  192.775       289.0             0.0            0.0  ...
# 33418     12.207   63.579        32.0             0.0            0.0  ...
# 33419     28.283      NaN        82.0             6.0            6.0  ...
#
#        Exportacoes_US$      Receitas_R$ Transferencias_correntes_R$  \
# 0                  NaN   25.511.889,220              18.911.068,400
# 1        1.777.256,000   63.002.672,933              45.304.154,440
# 2                  NaN   30.492.825,449              21.861.157,950
# 3                  NaN  140.538.926,872             100.508.822,360
# 4                  NaN   15.541.375,953              13.178.989,760
# ...                ...              ...                         ...
# 33415              NaN              NaN                         NaN
# 33416              NaN              NaN                         NaN
# 33417              NaN              NaN                         NaN
# 33418              NaN              NaN                         NaN
# 33419              NaN              NaN                         NaN
#
#       Transferencias_capital_R$ NrNascimentos NrObitosInfantis povoamento  UF  \
# 0                 1.665.392,540          80.0              0.0     32,065  SP
# 1                   538.882,600         299.0              3.0     55,065  MG
# 2                 1.048.458,040          59.0              2.0     14,930  SP
# 3                   871.234,340         272.0              2.0     22,698  RJ
# 4                     8.037,870          43.0              1.0      2,908  TO
# ...                         ...           ...              ...        ...  ..
# 33415                       NaN         135.0              3.0     83,287  AL
# 33416                       NaN         160.0              2.0      1,010  AP
# 33417                       NaN          32.0              1.0    180,059  PE
# 33418                       NaN         149.0              4.0      0,601  PA
# 33419                       NaN         106.0              1.0     40,847  MG
#
#                      Municipio    Regiao
# 0      Campina do Monte Alegre   Sudeste
# 1                  Elói Mendes   Sudeste
# 2                    Silveiras   Sudeste
# 3                 Silva Jardim   Sudeste
# 4       Pindorama do Tocantins     Norte
# ...                        ...       ...
# 33415            Monteirópolis  Nordeste
# 33416                    Amapá     Norte
# 33417      Fernando de Noronha  Nordeste
# 33418                     Faro     Norte
# 33419        Serra dos Aimorés   Sudeste
#
# [33420 rows x 24 columns]

# %%
for coluna in df.columns:
    df[coluna] = df[coluna].astype(str)  # Garante que é string
    df[coluna] = df[coluna].str.replace('.', '', regex=False)  # Remove separador de milhar
    df[coluna] = df[coluna].str.replace(',', '.', regex=False)  # Converte decimal
    df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
df

for coluna in df.columns:
  df[coluna] = df[coluna].astype(str)  # Garante que é string
  df[coluna] = df[coluna].str.replace('nan', '0', regex=False)  # Converte decimal

df
# Out:
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
# /tmp/ipykernel_9186/1254699193.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[coluna] = pd.to_numeric(df[coluna], errors='ignore')  # Converte para número, ignorando erros
#         Ano CDMunicipio Populacao PessoalOcupado PessoalAssalariado  \
# 0      2016     3509452      5932            854                537
# 1      2016     3123601     27505           5680               4778
# 2      2016     3552007      6193            668                580
# 3      2016     3305604     21279           3087               2669
# 4      2016     1717008      4534            212                183
# ...     ...         ...       ...            ...                ...
# 33415  2021     2705408      7171            463                436
# 33416  2021     1600105      9265            428                383
# 33417  2019     2605459      3061           2210               1773
# 33418  2020     1503002      7070            538                514
# 33419  2021     3166709      8725            852                773
#
#       VrSalarios     PIB QtEmpresas AreaPlantada_h AreaColhida_h  ...  \
# 0          13692  111190       2520            380           380  ...
# 1         104977  554663       6710             30            30  ...
# 2          12519   62441        830             00            00  ...
# 3          80161  403121       2900             00            00  ...
# 4           5309   48551        340            940           340  ...
# ...          ...     ...        ...            ...           ...  ...
# 33415      10502       0        320             00            00  ...
# 33416       9932       0        380             00            00  ...
# 33417      43093  192775       2890             00            00  ...
# 33418      12207   63579        320             00            00  ...
# 33419      28283       0        820             60            60  ...
#
#       Exportacoes_US$    Receitas_R$ Transferencias_correntes_R$  \
# 0                   0   25511889.220                18911068.400
# 1         1777256.000   63002672.933                45304154.440
# 2                   0   30492825.449                21861157.950
# 3                   0  140538926.872               100508822.360
# 4                   0   15541375.953                13178989.760
# ...               ...            ...                         ...
# 33415               0              0                           0
# 33416               0              0                           0
# 33417               0              0                           0
# 33418               0              0                           0
# 33419               0              0                           0
#
#       Transferencias_capital_R$ NrNascimentos NrObitosInfantis povoamento  UF  \
# 0                   1665392.540           800                0     32.065  SP
# 1                    538882.600          2990               30     55.065  MG
# 2                   1048458.040           590               20     14.930  SP
# 3                    871234.340          2720               20     22.698  RJ
# 4                      8037.870           430               10      2.908  TO
# ...                         ...           ...              ...        ...  ..
# 33415                         0          1350               30     83.287  AL
# 33416                         0          1600               20      1.010  AP
# 33417                         0           320               10    180.059  PE
# 33418                         0          1490               40      0.601  PA
# 33419                         0          1060               10     40.847  MG
#
#                      Municipio    Regiao
# 0      Campina do Monte Alegre   Sudeste
# 1                  Elói Mendes   Sudeste
# 2                    Silveiras   Sudeste
# 3                 Silva Jardim   Sudeste
# 4       Pindorama do Tocantins     Norte
# ...                        ...       ...
# 33415            Monteirópolis  Nordeste
# 33416                    Amapá     Norte
# 33417        Fer0do de Noronha  Nordeste
# 33418                     Faro     Norte
# 33419        Serra dos Aimorés   Sudeste
#
# [33420 rows x 24 columns]

# %%
df['Ano'] = df['Ano'].astype(int)
df['CDMunicipio'] = df['CDMunicipio'].astype(str)
df['Populacao'] = df['Populacao'].astype(int)
df['PessoalOcupado'] = df['PessoalOcupado'].astype(int)
df['PessoalAssalariado'] = df['PessoalAssalariado'].astype(int)
df['VrSalarios'] = df['VrSalarios'].astype(int)
df['PIB'] = df['PIB'].astype(int)
df['QtEmpresas'] = df['QtEmpresas'].astype(int)
df['AreaPlantada_h'] = df['AreaPlantada_h'].astype(int)
df['AreaColhida_h'] = df['AreaColhida_h'].astype(int)
df['VlProducaoAgricola'] = df['VlProducaoAgricola'].astype(int)
df['VlProducaoPecuaria'] = df['VlProducaoPecuaria'].astype(int)
df['Area'] = df['Area'].astype(float)
df['Importacoes_US$'] = df['Importacoes_US$'].astype(float)
df['Exportacoes_US$'] = df['Exportacoes_US$'].astype(float)
df['Receitas_R$'] = df['Receitas_R$'].astype(float)
df['Transferencias_correntes_R$'] = df['Transferencias_correntes_R$'].astype(float)
df['Transferencias_capital_R$'] = df['Transferencias_capital_R$'].astype(float)
df['NrNascimentos'] = df['NrNascimentos'].astype(int)
df['NrObitosInfantis'] = df['NrObitosInfantis'].astype(int)
df['povoamento'] = df['povoamento'].astype(float)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Dados agrupados por ano
df_grouped = df.groupby('Ano')[['AreaPlantada_h', 'AreaColhida_h']].sum().reset_index()

# Gráfico de linhas comparativo
plt.figure(figsize=(12, 6))
plt.plot(df_grouped['Ano'], df_grouped['AreaPlantada_h'], marker='o', label='Área Plantada')
plt.plot(df_grouped['Ano'], df_grouped['AreaColhida_h'], marker='o', label='Área Colhida')
plt.xlabel('Ano')
plt.ylabel('Área (hectares)')
plt.title('Área Plantada vs. Área Colhida ao Longo do Tempo')
plt.legend()
plt.grid(True)
plt.show()

# Discrepância anual
df_grouped['Discrepância'] = df_grouped['AreaPlantada_h'] - df_grouped['AreaColhida_h']
plt.figure(figsize=(12, 6))
plt.bar(df_grouped['Ano'], df_grouped['Discrepância'], color='red')
plt.xlabel('Ano')
plt.ylabel('Diferença (hectares)')
plt.title('Discrepância entre Área Plantada e Colhida por Ano')
plt.show()

# %% [markdown]
# Uma discrepância crescente pode indicar perdas por fatores climáticos, pragas ou mudanças no uso do solo.

# %%
# Scatter plot com tendência
plt.figure(figsize=(12, 6))
sns.regplot(x='povoamento', y='AreaPlantada_h', data=df, scatter_kws={'alpha':0.3})
plt.xlabel('Povoamento (habitantes por área)')
plt.ylabel('Área Plantada (hectares)')
plt.title('Relação entre Densidade Populacional e Área Plantada')
plt.show()

# %% [markdown]
# Uma correlação positiva sugeriria que regiões mais povoadas investem mais em agricultura.

# %%
# Scatter plot com correlação
plt.figure(figsize=(12, 6))
sns.scatterplot(x='VlProducaoAgricola', y='VlProducaoPecuaria', data=df, hue='Ano', palette='viridis')
plt.xlabel('Valor da Produção Agrícola (R$)')
plt.ylabel('Valor da Produção Pecuária (R$)')
plt.title('Correlação entre Produção Agrícola e Pecuária')
plt.show()

# Correlação estatística
correlacao = df[['VlProducaoAgricola', 'VlProducaoPecuaria']].corr().iloc[0,1]
print(f"Correlação: {correlacao:.2f}")
# Out:
# Correlação: 0.13

# %%
plt.figure(figsize=(12, 6))
sns.jointplot(
    x='VlProducaoAgricola', 
    y='VlProducaoPecuaria', 
    data=df, 
    kind='hex', 
    joint_kws={'gridsize': 30}, 
    marginal_kws={'color': 'darkgreen'}
)
plt.suptitle('Relação entre Produção Agrícola e Pecuária (Densidade e Tendência)', y=1.02)
plt.xlabel('Produção Agrícola (R$)')
plt.ylabel('Produção Pecuária (R$)')

# Adicionar linha de regressão
sns.regplot(x='VlProducaoAgricola', y='VlProducaoPecuaria', data=df, 
           scatter=False, color='red', line_kws={'linewidth': 2})

plt.show()

# %%
# Criar métrica proxy de mecanização
df['PessoalPorEmpresa'] = df['PessoalOcupado'] / df['QtEmpresas']

# Gráfico de linhas duplas (mecanização vs. empregabilidade)
plt.figure(figsize=(12, 6))
sns.lineplot(x='Ano', y='PessoalPorEmpresa', data=df, 
            estimator='median', errorbar=None, 
            label='Mecanização (Pessoal/Empresa)', linewidth=2.5)

sns.lineplot(x='Ano', y='PessoalOcupado', data=df, 
            estimator='median', errorbar=None, 
            label='Total Ocupados', linestyle='--')

plt.title('Evolução da Mecanização vs. Empregabilidade Agrícola')
plt.ylabel('Valor Normalizado')
plt.legend()
plt.grid(True)
plt.show()
